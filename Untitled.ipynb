# %%
import numpy as np # importing numpy to deal with arrays
from rake_nltk import Rake #rake is a NLP used to extract keywords form a text
import pandas as pd #importing pandas library to deal with datasets
lf=pd.read_csv("Book1.csv") #importing our datasets we have collected
r=Rake() #initializing the object rake

# %%
lf.head(10)
# Out:
#                                    Conditions  \
# 0                                  Chickenpox
# 1                Hand, foot and mouth disease
# 2                                   Head lice
# 3                                     Measles
# 4                                    Ringworm
# 5                    Rubella (German Measles)
# 6                                     Scabies
# 7                     School sores (Impetigo)
# 8  Slapped cheek (Human parvovirus infection)
# 9                               Campylobacter
#
#                           Disease spread by: Medium   \
# 0  Coughing, sneezing and contact with weeping bl...
# 1         Coughing, sneezing, and poor hand washing.
# 2  Direct contact with an infested person’s hair,...
# 3  Coughing and sneezing. Direct contact with an ...
# 4  Contact with infected skin, bedding and clothing.
# 5  Coughing and sneezing. Also direct contact wit...
# 6  Contact with infected skin, bedding and clothing.
# 7                Direct contact with infected sores.
# 8  Coughing and sneezing. The virus may be passed...
# 9  Undercooked food, contaminated water. Direct s...
#
#               Time duration  \
# 0                10-20 days
# 1                  3-5 days
# 2                       NaN
# 3                 7-21 days
# 4                 4-6 weeks
# 5                14-23 days
# 6                 4-9 weeks
# 7  depends upon the patient
# 8                 4-20 days
# 9                 1-10 days
#
#                                      Early symptomps  \
# 0  Fever and spots with a blister on top of each ...
# 1  Fever, flu-like symptoms – rash on soles and p...
# 2  Itchy scalp, especially behind ears. Occasiona...
# 3  Runny nose and eyes, cough and fever, followed...
# 4                            Flat, ring-shaped rash.
# 5  Fever, swollen neck glands and a rash on the f...
# 6                                        Itchy rash.
# 7  Blisters on the body which burst and turn into...
# 8             Red cheeks and lace-like rash on body.
# 9  Stomach pain, fever, nausea, diarrhoea and/or ...
#
#                                          Rest period  \
# 0  1 week from appearance of rash, or until all b...
# 1  Exclude until blisters have dried. If blisters...
# 2  None, but ECC/school should be informed. Treat...
# 3  5 days after the appearance of rash. Non-immun...
# 4          None, but skin contact should be avoided.
# 5  Until well and for 7 days from appearance of r...
# 6  Exclude until the day after appropriate treatm...
# 7  Until sores have dried up or 24 hours after an...
# 8                         Unnecessary unless unwell.
# 9  Until well and for 48 hours after the last epi...
#
#                                            Treatment
# 0  Keep yourself from  sun heat and outside atmos...
# 1  Keep yourself from  sun heat and outside atmos...
# 2                    Clean with clear water everyday
# 3    N/A but Fever reducers,\nAntibiotics, Vitamin A
# 4  prescription antifungal creams, lotions,powder...
# 5  take proper rest, if possible contact your doc...
# 6        apply permethrin cream and malathion lotion
# 7  prescription antibiotic ointments or creams, w...
# 8                          paracetamol or ibuprofen
# 9  Patients should drink extra fluids as long as ...

# %%
df= lf.filter(['Early symptomps','Conditions','Treatment'])#taking out only symptoms,disease,treatment from datasets.

# %%
df.head()
# Out:
#                                      Early symptomps  \
# 0  Fever and spots with a blister on top of each ...
# 1  Fever, flu-like symptoms – rash on soles and p...
# 2  Itchy scalp, especially behind ears. Occasiona...
# 3  Runny nose and eyes, cough and fever, followed...
# 4                            Flat, ring-shaped rash.
#
#                      Conditions  \
# 0                    Chickenpox
# 1  Hand, foot and mouth disease
# 2                     Head lice
# 3                       Measles
# 4                      Ringworm
#
#                                            Treatment
# 0  Keep yourself from  sun heat and outside atmos...
# 1  Keep yourself from  sun heat and outside atmos...
# 2                    Clean with clear water everyday
# 3    N/A but Fever reducers,\nAntibiotics, Vitamin A
# 4  prescription antifungal creams, lotions,powder...

# %%
dfs= df.filter(['Early symptomps']) # dataframe of symptoms only
dfc= df.filter(['Conditions']) #datafram of conditions only
dft= lf.filter(['Treatment'])        #dataframe of the treatment only

# %%
dfs
# Out:
#                                       Early symptomps
# 0   Fever and spots with a blister on top of each ...
# 1   Fever, flu-like symptoms – rash on soles and p...
# 2   Itchy scalp, especially behind ears. Occasiona...
# 3   Runny nose and eyes, cough and fever, followed...
# 4                             Flat, ring-shaped rash.
# 5   Fever, swollen neck glands and a rash on the f...
# 6                                         Itchy rash.
# 7   Blisters on the body which burst and turn into...
# 8              Red cheeks and lace-like rash on body.
# 9   Stomach pain, fever, nausea, diarrhoea and/or ...
# 10  Nausea, stomach pains, general sickness with j...
# 11                 Nausea, diarrhoea/and or vomiting.
# 12                 Nausea, diarrhoea/and or vomiting.
# 13    Diarrhoea (may be bloody), fever, stomach pain.
# 14  High incidence of bloody diarrhoea, stomach pa...
# 15  Sudden onset of fever with cough, sore throat,...
# 16  Headache, vomiting, sore throat. An untreated ...
# 17  Runny nose, persistent cough followed by “whoo...
# 18  Irritation and redness of eye. Sometimes there...
# 19  Generally unwell, fever, headache, vomiting, s...
# 20       Generally unwell, fever, headache, vomiting.
# 21  Pain in jaw, then swelling in front of ear and...
# 22  mild fever, headache,body pain, red eye, teary...
# 23  fever, headache,body pain, low oxygen,breathin...
# 24  Some have mild,flu-like symptoms. Dark urine, ...
# 25    fatigue,fever,sore throad,diarrohea,skin rashes
# 26  Redness on the outer ear, itch in ear, ear pai...
# 27                      Sore, dry or scratchy throat.
# 28  cough, swelling in the neck, changes in the vo...
# 29  A body temperature that is higher than normal,...
# 30  diarrhoea, vomiting, stomach pain, nausea, chi...
# 31  Black-and-blue marks that may appear red or pu...
# 32  Cramping or pain in the lower abdomen, lower b...
# 33  pain when you urinate, abnormal urine colour a...
# 34  Stiffness in the joints that make movements di...
# 35  Symptoms are usually only present at an advanc...
# 36  Sneezing, runny, stuffy and itchy nose, coughi...
# 37  Difficulty swallowing and the feeling of somet...
# 38  This can make you feel overly tired, depressed...
# 39  The lungs will produce lots of excess mucus, w...
# 40  Pain, swelling, bruising and limited movement ...
# 41   Excessive sweating that exceeds normal sweating.
# 42  Pain, tenderness and redness around the toenai...
# 43   Highest risk are the non-healthy populations. \n
# 44  Chills, fever,fatigue, productive or non-produ...
# 45  Viral disease. Fever >100.4oF, chills,headache...

# %%
dfc
# Out:
#                                     Conditions
# 0                                   Chickenpox
# 1                 Hand, foot and mouth disease
# 2                                    Head lice
# 3                                      Measles
# 4                                     Ringworm
# 5                     Rubella (German Measles)
# 6                                      Scabies
# 7                      School sores (Impetigo)
# 8   Slapped cheek (Human parvovirus infection)
# 9                                Campylobacter
# 10                                 Hepatitis A
# 11                                   Norovirus
# 12                                 Rotavirus
# 13                                   Shigella
# 14                    TEC/STEC (Verocytotoxin)
# 15        Influenza and Influenza-like illness
# 16                   Streptococcal sore throat
# 17                  Whooping cough (Pertussis)
# 18                   Conjunctivitis (Pink eye)
# 19                    Meningococcal Meningitis
# 20                          Meningitis – Viral
# 21                                       Mumps
# 22                                 Common cold
# 23                                    COVID-19
# 24                                 Hepatitis B
# 25                                         HIV
# 26              Otitis externa (swimmer’s ear)
# 27                   Pharyngitis (sore throat)
# 28                              Tussis (cough)
# 29                             Pyrexia (fever)
# 30               Gastroenteritis (stomach flu)
# 31                          Contusion (bruise)
# 32            Dysmenorrhoea (menstrual cramps)
# 33          Cystitis (urinary tract infection)
# 34                     Ankylosis (stiff joint)
# 35          Hyperlipidaemia (high cholesterol)
# 36               Allergic rhinitis (hay fever)
# 37            Gastro-oesophageal reflux (GERD)
# 38        Hypothyroidism (underactive thyroid)
# 39         Chronic bronchitis (lung infection)
# 40                    Sprain (ligament injury)
# 41          Hyperhidrosis (excessive sweating)
# 42           Onychocryptosis (ingrown toenail)
# 43                                   Pneumonia
# 44                                Tuberculosis
# 45                                       SARS

# %%
dft
# Out:
#                                             Treatment
# 0   Keep yourself from  sun heat and outside atmos...
# 1   Keep yourself from  sun heat and outside atmos...
# 2                     Clean with clear water everyday
# 3     N/A but Fever reducers,\nAntibiotics, Vitamin A
# 4   prescription antifungal creams, lotions,powder...
# 5   take proper rest, if possible contact your doc...
# 6         apply permethrin cream and malathion lotion
# 7   prescription antibiotic ointments or creams, w...
# 8                           paracetamol or ibuprofen
# 9   Patients should drink extra fluids as long as ...
# 10  entecavir (Baraclude), tenofovir (Viread), lam...
# 11                                                NaN
# 12                                                NaN
# 13     drink plenty of fluids to prevent dehydration.
# 14                                                NaN
# 15  Early antiviral treatment with neuraminidase i...
# 16  Gargle with 1/4 teaspoon (1.5 grams) of table ...
# 17                  Keeping breathing passages clear.
# 18  antibiotic, usually given topically as eye dro...
# 19            penicillin, ampicillin, and ceftriaxone
# 20                                                NaN
# 21  getting plenty of bed rest and fluids. using p...
# 22                          paracetamol or ibuprofen
# 23   paracetamol or ibuprofen and intake healthy diet
# 24                          vaccination-90% effective
# 25                               use precautions. N/A
# 26                      keep your ears clean and dry.
# 27  drinking plenty of fluids, gargling with warm ...
# 28                     Cough suppressants may be used
# 29                           paracetamol or ibuprofen
# 30                                      stay hydrated
# 31  Most contusions fade away without treatment. F...
# 32  pain medications, such as aspirin or paracetam...
# 33  Antibiotics are typically used to treat cystit...
# 34  Hot or cold compress may help relieving sympto...
# 35  Lifestyle changes is an important pillar of hy...
# 36  Treatment for the condition usually involves a...
# 37  In most cases, subtle changes to your diet and...
# 38  Medication is given to help replace the amount...
# 39  Getting lots of rest, drinking plenty of fluid...
# 40  rest, ice, compression and elevation. More rar...
# 41  Medications may include prescription antipersp...
# 42  For more severe ingrown toenails, partially or...
# 43     Masks. Vaccination available esp for children.
# 44  Mask pt and self. The TB organism dies when ex...
# 45  Fit tested N-95 respirators for caregivers wit...

# %%
dfsl=dfs.values.tolist()#converting datafrme of symptomps into list
dfcl=dfc.values.tolist()#converting dataframe of condition(disease) into list
dftl=dft.values.tolist()#converting dataframe of treatment into list
result=[]

# %%
print(dfsl)
# Out:
# [['Fever and spots with a blister on top of each spot.'], ['Fever, flu-like symptoms – rash on soles and palms and in the mouth.'], ['Itchy scalp, especially behind ears. Occasionally scalp infections that require treatment may develop.'], ['Runny nose and eyes, cough and fever, followed a few days later by a rash.'], ['Flat, ring-shaped rash.'], ['Fever, swollen neck glands and a rash on the face, scalp and body.'], ['Itchy rash.'], ['Blisters on the body which burst and turn into scabby sores.'], ['Red cheeks and lace-like rash on body.'], ['Stomach pain, fever, nausea, diarrhoea and/or vomiting.'], ['Nausea, stomach pains, general sickness with jaundice (yellow skin) appearing a few days later.'], ['Nausea, diarrhoea/and or vomiting.'], ['Nausea, diarrhoea/and or vomiting.'], ['Diarrhoea (may be bloody), fever, stomach pain.'], ['High incidence of bloody diarrhoea, stomach pain. High rate of hospitalisation and complications.'], ['Sudden onset of fever with cough, sore throat, muscular aches and a headache.'], ['Headache, vomiting, sore throat. An untreated sore throat could lead to Rheumatic fever.'], ['Runny nose, persistent cough followed by “whoop”, vomiting or breathlessness.'], ['Irritation and redness of eye. Sometimes there is a discharge.'], ['Generally unwell, fever, headache, vomiting, sometimes a rash. Urgent treatment is required.'], ['Generally unwell, fever, headache, vomiting.'], ['Pain in jaw, then swelling in front of ear and fever.'], ['mild fever, headache,body pain, red eye, teary eye, runny nose,cough'], ['fever, headache,body pain, low oxygen,breathing problems'], ['Some have mild,flu-like symptoms. Dark urine, light,colored stools, fatigue, fever & jaundice. Can develop acute hepatitis cirrhosis, liver cancer.'], ['fatigue,fever,sore throad,diarrohea,skin rashes'], ['Redness on the outer ear, itch in ear, ear pain, pus in ear.'], ['Sore, dry or scratchy throat.'], ['cough, swelling in the neck, changes in the voice and difficulty breathing'], ['A body temperature that is higher than normal, shivers and feeling cold, sweating, low appetite, lack of energy and feeling sleepy.'], ['diarrhoea, vomiting, stomach pain, nausea, chills, headache, and muscle aches.'], ['Black-and-blue marks that may appear red or purple at first. The bruised area and surrounding skin may also be tender to touch.'], ['Cramping or pain in the lower abdomen, lower back pain that radiates down the legs, nausea, vomiting, diarrhoea, fatigue, headaches and weakness.'], ['pain when you urinate, abnormal urine colour and foul-smelling urine, a burning or stinging sensation when urinating, a frequent urge to urinate as well as abdominal and pelvic pain and pressure.'], ['Stiffness in the joints that make movements difficult. This may be accompanied by pain, swelling and inflammation in the joints.'], ['Symptoms are usually only present at an advanced state, manifesting as a heart attack or stroke.'], ['Sneezing, runny, stuffy and itchy nose, coughing, sore throat, itchy and watery eyes and dry, itchy skin.'], ['Difficulty swallowing and the feeling of something stuck in your throat'], ['This can make you feel overly tired, depressed and constipated, slow down your heart rate, make it more difficult to lose weight, and mess up your menstrual cycle.\xa0'], ['The lungs will produce lots of excess mucus, which means you’ll be coughing more than usual. You may also have a sore throat, runny nose, headaches and chest pain.\xa0'], ['Pain, swelling, bruising and limited movement ability at the affected joint.'], ['Excessive sweating that exceeds normal sweating.'], ['Pain, tenderness and redness around the toenail, swelling or the toe around the nail and infection of the tissue around the toenail.'], ['Highest risk are the non-healthy populations. \n'], ['Chills, fever,fatigue, productive or non-productive chronic cough, weight loss, night sweats, hemoptysis.'], ['Viral disease. Fever >100.4oF, chills,headache, body achiness, respiratory comp ...

# %%
#extracting keywords from each sympotoms using rake 

a=[]
b=[]
for word in dfsl:
        wl= ' '.join(map(str, word))
        z=r.extract_keywords_from_text(wl) #extracting keywors
        bar=r.get_ranked_phrases_with_scores() #extracting keywords and their priority scores
        for scores,bars in bar: #exttracting only keywords 
            a.append(bars) # adding those keywords into a list
        a=sorted(a) #sorting out the list of keywords
        b.append(a) # adding list of those keywords into another list of symptomps
        a=[]


print(b)
# Out:
# [['blister', 'fever', 'spot', 'spots', 'top'], ['fever', 'flu', 'like symptoms – rash', 'mouth', 'palms', 'soles'], ['especially behind ears', 'itchy scalp', 'occasionally scalp infections', 'require treatment may develop'], ['cough', 'days later', 'eyes', 'fever', 'followed', 'rash', 'runny nose'], ['flat', 'ring', 'shaped rash'], ['body', 'face', 'fever', 'rash', 'scalp', 'swollen neck glands'], ['itchy rash'], ['blisters', 'body', 'burst', 'scabby sores', 'turn'], ['body', 'lace', 'like rash', 'red cheeks'], ['diarrhoea', 'fever', 'nausea', 'stomach pain', 'vomiting'], ['appearing', 'days later', 'general sickness', 'jaundice', 'nausea', 'stomach pains', 'yellow skin'], ['diarrhoea', 'nausea', 'vomiting'], ['diarrhoea', 'nausea', 'vomiting'], ['bloody ), fever', 'diarrhoea', 'may', 'stomach pain'], ['bloody diarrhoea', 'complications', 'high incidence', 'high rate', 'hospitalisation', 'stomach pain'], ['cough', 'fever', 'headache', 'muscular aches', 'sore throat', 'sudden onset'], ['headache', 'rheumatic fever', 'sore throat', 'untreated sore throat could lead', 'vomiting'], ['breathlessness', 'persistent cough followed', 'runny nose', '“ whoop ”, vomiting'], ['discharge', 'eye', 'irritation', 'redness', 'sometimes'], ['fever', 'generally unwell', 'headache', 'rash', 'required', 'sometimes', 'urgent treatment', 'vomiting'], ['fever', 'generally unwell', 'headache', 'vomiting'], ['ear', 'fever', 'front', 'jaw', 'pain', 'swelling'], ['body pain', 'cough', 'headache', 'mild fever', 'red eye', 'runny nose', 'teary eye'], ['body pain', 'breathing problems', 'fever', 'headache', 'low oxygen'], ['colored stools', 'dark urine', 'develop acute hepatitis cirrhosis', 'fatigue', 'fever', 'flu', 'jaundice', 'light', 'like symptoms', 'liver cancer', 'mild'], ['diarrohea', 'fatigue', 'fever', 'skin rashes', 'sore throad'], ['ear', 'ear', 'ear pain', 'itch', 'outer ear', 'pus', 'redness'], ['dry', 'scratchy throat', 'sore'], ['changes', 'cough', 'difficulty breathing', 'neck', 'swelling', 'voice'], ['body temperature', 'energy', 'feeling cold', 'feeling sleepy', 'higher', 'lack', 'low appetite', 'normal', 'shivers', 'sweating'], ['chills', 'diarrhoea', 'headache', 'muscle aches', 'nausea', 'stomach pain', 'vomiting'], ['black', 'blue marks', 'bruised area', 'first', 'may appear red', 'purple', 'surrounding skin may also', 'tender', 'touch'], ['cramping', 'diarrhoea', 'fatigue', 'headaches', 'legs', 'lower abdomen', 'lower back pain', 'nausea', 'pain', 'radiates', 'vomiting', 'weakness'], ['abdominal', 'abnormal urine colour', 'burning', 'foul', 'frequent urge', 'pain', 'pelvic pain', 'pressure', 'smelling urine', 'stinging sensation', 'urinate', 'urinate', 'urinating', 'well'], ['accompanied', 'inflammation', 'joints', 'joints', 'make movements difficult', 'may', 'pain', 'stiffness', 'swelling'], ['advanced state', 'heart attack', 'manifesting', 'present', 'stroke', 'symptoms', 'usually'], ['coughing', 'dry', 'itchy', 'itchy nose', 'itchy skin', 'runny', 'sneezing', 'sore throat', 'stuffy', 'watery eyes'], ['difficulty swallowing', 'feeling', 'something stuck', 'throat'], ['constipated', 'depressed', 'difficult', 'feel overly tired', 'heart rate', 'lose weight', 'make', 'make', 'menstrual cycle', 'mess', 'slow'], ['chest pain', 'coughing', 'excess mucus', 'headaches', 'lungs', 'may also', 'means', 'produce lots', 'runny nose', 'sore throat', 'usual', '’'], ['affected joint', 'bruising', 'limited movement ability', 'pain', 'swelling'], ['exceeds normal sweating', 'excessive sweating'], ['infection', 'nail', 'pain', 'redness around', 'swelling', 'tenderness', 'tissue around', 'toe around', 'toenail', 'toenail'], ['healthy populations', 'highest risk', 'non'], ['chills', 'fatigue', 'fever', 'hemoptysis', 'night sweats', 'non', 'productive', 'productive chronic cough', 'weight loss'], ['100', '4of', 'body achiness', 'chills', 'fever', 'headache', 'respiratory complaints', 'viral disease']]

# %%
print(dfcl[19])
print(len(b))
# Out:
# ['Meningococcal Meningitis']
# 46

# %%
all_of_data=[]
for i in range(0,len(b)):
    all_of_data.append(b[i])

# %%
print(all_of_data)
# Out:
# [['blister', 'fever', 'spot', 'spots', 'top'], ['fever', 'flu', 'like symptoms – rash', 'mouth', 'palms', 'soles'], ['especially behind ears', 'itchy scalp', 'occasionally scalp infections', 'require treatment may develop'], ['cough', 'days later', 'eyes', 'fever', 'followed', 'rash', 'runny nose'], ['flat', 'ring', 'shaped rash'], ['body', 'face', 'fever', 'rash', 'scalp', 'swollen neck glands'], ['itchy rash'], ['blisters', 'body', 'burst', 'scabby sores', 'turn'], ['body', 'lace', 'like rash', 'red cheeks'], ['diarrhoea', 'fever', 'nausea', 'stomach pain', 'vomiting'], ['appearing', 'days later', 'general sickness', 'jaundice', 'nausea', 'stomach pains', 'yellow skin'], ['diarrhoea', 'nausea', 'vomiting'], ['diarrhoea', 'nausea', 'vomiting'], ['bloody ), fever', 'diarrhoea', 'may', 'stomach pain'], ['bloody diarrhoea', 'complications', 'high incidence', 'high rate', 'hospitalisation', 'stomach pain'], ['cough', 'fever', 'headache', 'muscular aches', 'sore throat', 'sudden onset'], ['headache', 'rheumatic fever', 'sore throat', 'untreated sore throat could lead', 'vomiting'], ['breathlessness', 'persistent cough followed', 'runny nose', '“ whoop ”, vomiting'], ['discharge', 'eye', 'irritation', 'redness', 'sometimes'], ['fever', 'generally unwell', 'headache', 'rash', 'required', 'sometimes', 'urgent treatment', 'vomiting'], ['fever', 'generally unwell', 'headache', 'vomiting'], ['ear', 'fever', 'front', 'jaw', 'pain', 'swelling'], ['body pain', 'cough', 'headache', 'mild fever', 'red eye', 'runny nose', 'teary eye'], ['body pain', 'breathing problems', 'fever', 'headache', 'low oxygen'], ['colored stools', 'dark urine', 'develop acute hepatitis cirrhosis', 'fatigue', 'fever', 'flu', 'jaundice', 'light', 'like symptoms', 'liver cancer', 'mild'], ['diarrohea', 'fatigue', 'fever', 'skin rashes', 'sore throad'], ['ear', 'ear', 'ear pain', 'itch', 'outer ear', 'pus', 'redness'], ['dry', 'scratchy throat', 'sore'], ['changes', 'cough', 'difficulty breathing', 'neck', 'swelling', 'voice'], ['body temperature', 'energy', 'feeling cold', 'feeling sleepy', 'higher', 'lack', 'low appetite', 'normal', 'shivers', 'sweating'], ['chills', 'diarrhoea', 'headache', 'muscle aches', 'nausea', 'stomach pain', 'vomiting'], ['black', 'blue marks', 'bruised area', 'first', 'may appear red', 'purple', 'surrounding skin may also', 'tender', 'touch'], ['cramping', 'diarrhoea', 'fatigue', 'headaches', 'legs', 'lower abdomen', 'lower back pain', 'nausea', 'pain', 'radiates', 'vomiting', 'weakness'], ['abdominal', 'abnormal urine colour', 'burning', 'foul', 'frequent urge', 'pain', 'pelvic pain', 'pressure', 'smelling urine', 'stinging sensation', 'urinate', 'urinate', 'urinating', 'well'], ['accompanied', 'inflammation', 'joints', 'joints', 'make movements difficult', 'may', 'pain', 'stiffness', 'swelling'], ['advanced state', 'heart attack', 'manifesting', 'present', 'stroke', 'symptoms', 'usually'], ['coughing', 'dry', 'itchy', 'itchy nose', 'itchy skin', 'runny', 'sneezing', 'sore throat', 'stuffy', 'watery eyes'], ['difficulty swallowing', 'feeling', 'something stuck', 'throat'], ['constipated', 'depressed', 'difficult', 'feel overly tired', 'heart rate', 'lose weight', 'make', 'make', 'menstrual cycle', 'mess', 'slow'], ['chest pain', 'coughing', 'excess mucus', 'headaches', 'lungs', 'may also', 'means', 'produce lots', 'runny nose', 'sore throat', 'usual', '’'], ['affected joint', 'bruising', 'limited movement ability', 'pain', 'swelling'], ['exceeds normal sweating', 'excessive sweating'], ['infection', 'nail', 'pain', 'redness around', 'swelling', 'tenderness', 'tissue around', 'toe around', 'toenail', 'toenail'], ['healthy populations', 'highest risk', 'non'], ['chills', 'fatigue', 'fever', 'hemoptysis', 'night sweats', 'non', 'productive', 'productive chronic cough', 'weight loss'], ['100', '4of', 'body achiness', 'chills', 'fever', 'headache', 'respiratory complaints', 'viral disease']]

# %%
#taking user input as symptoms and giving the output as disease caused by and its treatment  
sympt= input('please write down the symptoms  :  ')
sz=r.extract_keywords_from_text(sympt)# extracting keywords from our user input a
sb=r.get_ranked_phrases_with_scores()
sl=[]
for scores,keywords in sb:
    sl.append(keywords) 
sl=sorted(sl)                         # sorted list of the keywords from user input

for i in range(len(b)):
    if sl== b[i]:
        
        break
            
        
print("considering the symptoms it seems like you have been infected with \n\n",dfcl[i])
print("and it's treatment is ",dftl[i])
# Out:
# please write down the symptoms  :   fatigue,fever,sore throad,diarrohea,skin rashes
# considering the symptoms it seems like you have been infected with
#
#  ['HIV']
# and it's treatment is  ['use precautions. N/A']

# %%
a=dfsl[0]
print(a)
# Out:
# ['Fever and spots with a blister on top of each spot.']

# %%
st = ' '.join(map(str, a))

# %%
print(st)
# Out:
# Fever and spots with a blister on top of each spot.

# %%
r=Rake()
r.extract_keywords_from_text(st)

# %%
print(r.get_ranked_phrases_with_scores())
# Out:
# [(1.0, 'top'), (1.0, 'spots'), (1.0, 'spot'), (1.0, 'fever'), (1.0, 'blister')]
